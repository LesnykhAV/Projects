# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
# Импорт необходимых библиотек
from google.colab import drive
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import csv

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
# Монтируем Google Диск
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Загружаем данные
hh_data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Project_1_dataframe/dst-3.0_16_1_hh_database.csv', sep=';', encoding='utf-8')

# %%
# Размерность датафрейма
hh_data.shape
# Out:
# (44744, 12)

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
# Выводим несколько первых строк датафрейма
display(hh_data.head(2))
# Выводим несколько последних строк датафрейма
display(hh_data.tail(2))
# Out:
#                                  Пол, возраст          ЗП  \
# 0  Мужчина ,  39 лет , родился 27 ноября 1979  29000 руб.
# 1   Мужчина ,  60 лет , родился 20 марта 1959  40000 руб.
#
#   Ищет работу на должность:  \
# 0   Системный администратор
# 1      Технический писатель
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
#
#                                               График  \
# 0  гибкий график, полный день, сменный график, ва...
# 1  гибкий график, полный день, сменный график, уд...
#
#                                          Опыт работы  \
# 0  Опыт работы 16 лет 10 месяцев  Август 2010 — п...
# 1  Опыт работы 19 лет 5 месяцев  Январь 2000 — по...
#
#   Последнее/нынешнее место работы  \
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %%
hh_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
# Проверка отсутствующих значений
pd.isna(hh_data).sum()[pd.isna(hh_data).sum() > 0]
# Out:
# Опыт работы                        168
# Последнее/нынешнее место работы      1
# Последняя/нынешняя должность         2
# dtype: int64

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
hh_data.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
# Создаем функцию-преобразование для определения категории образования на основе первых двух слов в столбце 'Образование и ВУЗ'
def categorize_education(value):
    words = str(value).split()
    if len(words) >= 2:
        edu_level = words[0] + ' ' + words[1]
        if 'Высшее' in edu_level:
            return 'высшее'
        elif 'Неоконченное высшее' in edu_level:
            return 'неоконченное высшее'
        elif 'Среднее специальное'in edu_level:
            return 'среднее специальное'
        elif 'Среднее'in edu_level:
            return 'среднее'

# Создаем новый столбец 'Образование' в датафрейме 'hh_data'
hh_data['Образование'] = hh_data['Образование и ВУЗ'].apply (categorize_education)

# Удаляем признак 'Образование и ВУЗ'
hh_data = hh_data.drop(['Образование и ВУЗ'], axis=1)
display(hh_data.head(2))
# Out:
#                                  Пол, возраст          ЗП  \
# 0  Мужчина ,  39 лет , родился 27 ноября 1979  29000 руб.
# 1   Мужчина ,  60 лет , родился 20 марта 1959  40000 руб.
#
#   Ищет работу на должность:  \
# 0   Системный администратор
# 1      Технический писатель
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
#
#                                               График  \
# 0  гибкий график, полный день, сменный график, ва...
# 1  гибкий график, полный день, сменный график, уд...
#
#                                          Опыт работы  \
# 0  Опыт работы 16 лет 10 месяцев  Август 2010 — п...
# 1  Опыт работы 19 лет 5 месяцев  Январь 2000 — по...
#
#   Последнее/нынешнее место работы  \
# ...

# %%
# Проверим количество уникальных категорий образования в столбце 'Образование'
hh_data['Образование'].nunique()
# Out:
# 4

# %%
# Проверим количество вхождений каждого уникального значения категории образования в столбце 'Образование'
hh_data['Образование'].value_counts()
# Out:
# Образование
# высшее                 33863
# среднее специальное     5765
# неоконченное высшее     4557
# среднее                  559
# Name: count, dtype: int64

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
# Функция для извлечения пола
def get_gender(value):
    if 'Мужчина' in value:
        return 'М'
    else:
        return 'Ж'

# Функция для извлечения возраста
def get_age(value):
    value_splitted = value.split(' ')
    year_words=['год', 'года', 'лет']
    for index, item in enumerate (value_splitted):
        if item in year_words:
            return int(value_splitted[index-1])

# Создаем новые столбцы 'Пол' и 'Возраст'
hh_data['Пол'] = hh_data['Пол, возраст'].apply(get_gender)
hh_data['Возраст'] = hh_data['Пол, возраст'].apply(get_age)

# Удаляем признак 'Пол, возраст'
hh_data = hh_data.drop(columns=['Пол, возраст'])
display(hh_data.head(2))
# Out:
#            ЗП Ищет работу на должность:  \
# 0  29000 руб.   Системный администратор
# 1  40000 руб.      Технический писатель
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
#
#                                               График  \
# 0  гибкий график, полный день, сменный график, ва...
# 1  гибкий график, полный день, сменный график, уд...
#
#                                          Опыт работы  \
# 0  Опыт работы 16 лет 10 месяцев  Август 2010 — п...
# 1  Опыт работы 19 лет 5 месяцев  Январь 2000 — по...
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# 1    Временный трудовой коллектив
#
#                        Последняя/нынешняя должность Обновление резюме  \
# ...

# %%
# Сколько процентов женских резюме представлено в наших данных? Ответ округлите до сотых.
display(round(hh_data[hh_data['Пол'] == 'Ж'].shape[0] / hh_data['Пол'].shape[0] * 100, 2))
# Чему равен средний возраст соискателей? Ответ округлите до десятых.
display(round(hh_data['Возраст'].mean(), 1))
# Out:
# 19.07
# 32.2

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
# Функция для преобразования опыта работы в месяцы
def get_experience(value):
    # Проверяем, является ли значение NaN или "Не указано"
    if value is np.nan or value == 'Не указано':
        return None
# Создаём списки признаков опыта работы в годах и месяцев
    year_words = ['лет', 'год', 'года']
    month_words = ['месяц', 'месяца', 'месяцев']
# В результате получаем список слов в строке и заносим его в переменную experience_list
    experience_list = value.split(' ')[:7]
    years = 0
    months = 0
# Делаем проверку на то, что полученный остаток содержит год или месяц
    for index, item in enumerate(experience_list):
        if item in year_words:
            years = int(experience_list[index-1])
        if item in month_words:
            months = int(experience_list[index-1])
    return int(years*12 + months) # Возвращаем количество месяцев

# Создаем новый столбец (признак) 'Опыт работы (месяц)'
hh_data['Опыт работы (месяц)'] = hh_data['Опыт работы'].apply(get_experience)

# Удаляем признак 'Опыт работы'
hh_data = hh_data.drop('Опыт работы', axis=1)
display(hh_data.head(2))
# Out:
#            ЗП Ищет работу на должность:  \
# 0  29000 руб.   Системный администратор
# 1  40000 руб.      Технический писатель
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
#
#                                               График  \
# 0  гибкий график, полный день, сменный график, ва...
# 1  гибкий график, полный день, сменный график, уд...
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# 1    Временный трудовой коллектив
#
#                        Последняя/нынешняя должность Обновление резюме  \
# 0                           Системный администратор  16.04.2019 15:59
# 1  Менеджер проекта, Аналитик, Технический писатель  12.04.2019 08:42
#
# ...

# %%
# Чему равен медианный опыт работы (в месяцах) в нашей таблице?
display(hh_data['Опыт работы (месяц)'].median())
# Out:
# 100.0

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
# Список городов-миллионников
million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск', 'Омск', 'Самара',
                  'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград' ]

# Функция для извлечения города
def get_city(value):
# Список городов для проверки
    check_list = ['Москва', 'Санкт-Петербург']
# В результате получаем список слов в строке и заносим его в переменную city_list
    city_list = value.split(' , ')
# Обрезаем список, оставляя в нём только первый элемент и заносим в переменную city_type
    city_type = city_list[0]
# Проверяем, если город в списке check_list или в million_cities
    if city_type in check_list:
        return city_type
    elif city_type in million_cities:
        return 'город-миллионник'
    else:
        return 'другие'

# Функция для извлечения информации о готовности к переезду
def get_moving(value):
    if ('не готов к переезду' in value) or ('не готова к переезду' in value):
        return False
    else:
        return True

# Функция для извлечения информации о готовности к командировкам
def get_trips(value):
    if ('командировка' in value):
        if ('не готов к командировкам' in value) or('не готова к командировкам' in value):
            return False
        else:
            return True
    else:
        return False

# Создаем новые столбцы (признаки): 'Город', 'Готовность к переезду', 'Готовность к командировкам'
hh_data['Город'] = hh_data['Город, переезд, командировки'].apply(get_city)
hh_data['Готовность к переезду'] = hh_data['Город, переезд, командировки'].apply(get_moving)
hh_data['Готовность к командировкам'] = hh_data['Город, переезд, командировки'].apply(get_trips)

# Удаляем признак 'Город, переезд, командировки'
hh_data = hh_data.drop('Город, переезд, командировки', axis=1)
display(hh_data.head(2))
# Out:
#            ЗП Ищет работу на должность:  \
# 0  29000 руб.   Системный администратор
# 1  40000 руб.      Технический писатель
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
#
#                                               График  \
# 0  гибкий график, полный день, сменный график, ва...
# 1  гибкий график, полный день, сменный график, уд...
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# 1    Временный трудовой коллектив
#
#                        Последняя/нынешняя должность Обновление резюме  \
# 0                           Системный администратор  16.04.2019 15:59
# 1  Менеджер проекта, Аналитик, Технический писатель  12.04.2019 08:42
#
#                              Авто          Образование Пол  Возраст  \
# 0  Имеется собственный автомобиль  неоконченное высшее   М       39
# ...

# %%
# Сколько процентов соискателей живут в Санкт-Петербурге? Ответ округлите до целого.
display(round(hh_data[hh_data['Город'] == 'Санкт-Петербург'].shape[0] / hh_data.shape[0]*100))
# Сколько процентов соискателей готовы одновременно и к переездам, и к командировкам? Ответ округлите до целого.
display(round(hh_data[(hh_data['Готовность к переезду'] == True) & (hh_data['Готовность к командировкам'] == True)].shape[0] / hh_data.shape[0]*100))
# Out:
# 11
# 32

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
# Приводим значения в столбцах 'Занятость' и 'График' к нижнему регистру
hh_data['Занятость'] = hh_data['Занятость'].str.lower()
hh_data['График'] = hh_data['График'].str.lower()

# Создаем списки типов занятости и графиков работы
employments = ['полная занятость', 'частичная занятость', 'проектная работа', 'волонтерство', 'стажировка']
charts = ['полный день', 'сменный график', 'гибкий график', 'удаленная работа', 'вахтовый метод']

# Цикл по типам занятости, который создает признак-мигалку и заполняет его булевым значением
for employment in employments:
    hh_data[employment.capitalize()] = hh_data['Занятость'].apply(lambda x: employment in x)

# Цикл по типам графикам работы, который создает признак-мигалку и заполняет его булевым значением
for schedule in charts:
    hh_data[schedule.capitalize()] = hh_data['График'].apply(lambda x: schedule in x)

# Сколько людей ищут проектную работу и волонтёрство (в обоих столбцах стоит True)?
print(hh_data[hh_data['Проектная работа'] & hh_data['Волонтерство']].shape[0])

# Сколько людей хотят работать вахтовым методом и с гибким графиком (в обоих столбцах стоит True)?
print(hh_data[hh_data['Вахтовый метод'] & hh_data['Гибкий график']].shape[0])

# Удаляем исходные столбцы 'Занятость' и 'График'
hh_data = hh_data.drop(['Занятость', 'График'], axis=1)
display(hh_data.head(2))
# Out:
# 436
# 2311
#            ЗП Ищет работу на должность: Последнее/нынешнее место работы  \
# 0  29000 руб.   Системный администратор         МАОУ "СОШ № 1 г.Немана"
# 1  40000 руб.      Технический писатель    Временный трудовой коллектив
#
#                        Последняя/нынешняя должность Обновление резюме  \
# 0                           Системный администратор  16.04.2019 15:59
# 1  Менеджер проекта, Аналитик, Технический писатель  12.04.2019 08:42
#
#                              Авто          Образование Пол  Возраст  \
# 0  Имеется собственный автомобиль  неоконченное высшее   М       39
# 1                      Не указано               высшее   М       60
#
#    Опыт работы (месяц)  ... Полная занятость  Частичная занятость  \
# 0                202.0  ...             True                 True
# 1                233.0  ...             True                 True
#
#    Проектная работа  Волонтерство  Стажировка  Полный день  Сменный график  \
# ...

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
# Загружаем данные о курсах обмена валют
exchange_rates = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Project_1_dataframe/ExchangeRates.csv', sep=',')

# Преобразуем столбцы с датами в формат datetime и извлечем только дату без времени
hh_data['Обновление резюме'] = pd.to_datetime(hh_data['Обновление резюме'], dayfirst=True).dt.date
exchange_rates['date'] = pd.to_datetime(exchange_rates['date'], dayfirst=True).dt.date

# Создаем копию данных
hh_copy = hh_data.copy()

# Извлекаем числовую часть зарплаты и приводим ее к целому типу
hh_copy['Зарплата'] = hh_copy['ЗП'].str.split(" ", expand=True)[0].astype(int)

# Извлекаем валюту зарплаты
hh_copy['Валюта'] = hh_data['ЗП'].str.split(" ", expand=True)[1]

# Выводим количество вакансий по каждой валюте
display(hh_copy['Валюта'].value_counts())

# Заменяем обозначения валют на стандартизированные трехбуквенные коды
hh_copy['Валюта'] = hh_copy['Валюта'].replace(['руб.', 'KZT', 'USD', 'бел.руб.', 'EUR', 'грн.', 'сум', 'KGS', 'AZN'],
                                    ['RUB', 'KZT', 'USD', 'BYN', 'EUR', 'UAH', 'UZS', 'KGS', 'AZN'])

# Объединяем данные о зарплатах и курсы обмена валют по валюте и дате
merge_hh = hh_copy.merge(
    exchange_rates,
    left_on=['Валюта', 'Обновление резюме'],
    right_on=['currency', 'date'],
    how='left'
)

# Заполняем отсутствующие значения в столбцах close и proportion значением 1.
merge_hh['close'] = merge_hh['close'].fillna(1)
merge_hh['proportion'] = merge_hh['proportion'].fillna(1)
# Рассчитываем зарплату в рублях, умножая зарплату на курс валюты и деля на пропорцию
hh_data['ЗП (руб)'] = merge_hh['close'] * merge_hh['Зарплата'] / merge_hh['proportion']

# Чему равна желаемая медианная заработная плата соискателей в нашей таблице (в рублях)?
print(round(hh_data['ЗП (руб)'].median()/1000))

# Удаляем исходный признак 'ЗП'
hh = hh_data.drop('ЗП', axis=1)
display(hh_data.head(2))
# Out:
# <ipython-input-36-937c497e6d06>:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   exchange_rates['date'] = pd.to_datetime(exchange_rates['date'], dayfirst=True).dt.date
# Валюта
# руб.        42471
# KZT          1108
# USD           628
# бел.руб.      329
# EUR           106
# грн.           73
# сум            20
# KGS             6
# AZN             3
# Name: count, dtype: int64
# 59
#            ЗП Ищет работу на должность: Последнее/нынешнее место работы  \
# 0  29000 руб.   Системный администратор         МАОУ "СОШ № 1 г.Немана"
# 1  40000 руб.      Технический писатель    Временный трудовой коллектив
#
#                        Последняя/нынешняя должность Обновление резюме  \
# 0                           Системный администратор        2019-04-16
# 1  Менеджер проекта, Аналитик, Технический писатель        2019-04-12
#
# ...

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
plt.figure(figsize=(15, 6))

# Построим гистограмму распределения возраста соискателей
plt.subplot(1, 2, 1)
sns.histplot(hh_data['Возраст'], bins=30, kde=True)
plt.title('Гистограмма распределения возраста соискателей')
plt.xlabel('Возраст')
plt.ylabel('Количество')

# Построим коробчатую диаграмму распределения возраста соискателей
plt.subplot(1, 2, 2)
sns.boxplot(x=hh_data['Возраст'])
plt.title('Коробчатая диаграмма распределения возраста соискателей')
plt.xlabel('Возраст')
# Out:
# Text(0.5, 0, 'Возраст')

# %%
# Ответы на основные вопросы по распределению возраста соискателей:

# Чему равна мода распределения?
age_mode = hh_data['Возраст'].mode()[0]
print(f"Мода распределения возраста соискателей: {age_mode}")

# Каковы предельные значения признака?
age_min = hh_data['Возраст'].min()
age_max = hh_data['Возраст'].max()
print(f"Минимальный возраст: {age_min}")
print(f"Максимальный возраст: {age_max}")

# В каком примерном интервале находится возраст большинства соискателей?
age_q25 = hh_data['Возраст'].quantile(0.25) # вычисляем первый (25-й процентиль)
age_q75 = hh_data['Возраст'].quantile(0.75) # вычисляем третий (75-й процентиль)
print(f"Нижний квартиль: {age_q25}")
print(f"Верхний квартиль: {age_q75}")

# Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# Для определения анамолий (выбросов) воспользуемся методом межквартильного размаха (IQR)
age_iqr = age_q75 - age_q25
# Вычислим нижнюю и верхнюю границы для выявления аномальных значений
# (если значение находится ниже нижней границы (age_lower_bound) или выше верхней границы (age_upper_bound), то оно считается аномальным)
age_lower_bound = age_q25 - 1.5 * age_iqr
print(f"Нижняя граница аномальных значений: {age_lower_bound}")
age_upper_bound = age_q75 + 1.5 * age_iqr
print(f"Верхняя граница аномальных значений: {age_upper_bound}")
anomalies = hh_data[(hh_data['Возраст'] < age_lower_bound) | (hh_data['Возраст'] > age_upper_bound)]
print(f"Количество аномальных значений: {anomalies.shape[0]}")
print(f"Аномальные значения: {anomalies['Возраст'].unique()}")
# Out:
# Мода распределения возраста соискателей: 30
# Минимальный возраст: 14
# Максимальный возраст: 100
# Нижний квартиль: 27.0
# Верхний квартиль: 36.0
# Нижняя граница аномальных значений: 13.5
# Верхняя граница аномальных значений: 49.5
# Количество аномальных значений: 1774
# Аномальные значения: [ 60  59  53  54  62  72  61  50  58  57  52  56  51  71  63  55  64  68
#   73  66  65  77  67  69  76  70 100]

# %% [markdown]
# **Выводы:** <br>
# 1. Мода распределения составляет 30 лет, т.е. данный возраст встречается чаще, чем любой другой возраст в наборе данных соискателей.<br>
# 2. Крайние значения возраста среди соискателей: минимальный возраст - 14 лет, максимальный возраст - 100 лет.
# 3. Возраст большинства соискателей находится в интервале: от 27 до 36 лет.
# 4. Распределения возраста соискателей можно считать нормальным, согласно графикам аномальные значения начинаются с 50 лет, но с 50 до 70 лет люди вполне возможно могут искать работу (подработку, дополнительный доход) и следовательно можно считать выбросами значения после 75 лет.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
plt.figure(figsize=(15, 6))

# Построим гистограмму распределения опыта работы соискателей
plt.subplot(1, 2, 1)
sns.histplot(hh_data['Опыт работы (месяц)'].dropna(), bins=30, kde=True)
plt.title('Гистограмма распределения опыта работы соискателей')
plt.xlabel('Опыт работы (месяц)')
plt.ylabel('Количество')

# Построим коробчатую диаграмму распределения опыта работы соискателей
plt.subplot(1, 2, 2)
sns.boxplot(hh_data['Опыт работы (месяц)'])
plt.title('Коробчатая диаграмма распределения опыта работы соискателей')
plt.xlabel('Опыт работы (месяц)')
# Out:
# Text(0.5, 0, 'Опыт работы (месяц)')

# %%
# Ответы на основные вопросы по распределению опыта соискателей:

# Чему равна мода распределения?
experience_mode = hh_data['Опыт работы (месяц)'].mode()[0]
print(f"Мода распределения опыта работа (месяц) соискателей: {experience_mode}")

# Каковы предельные значения признака?
experience_min = hh_data['Опыт работы (месяц)'].min()
experience_max = hh_data['Опыт работы (месяц)'].max()
print(f"Минимальный опыт работы (месяц): {experience_min}")
print(f"Максимальный опыт работы (месяц): {experience_max}")

# В каком примерном интервале находится опыт работы большинства соискателей?
experience_q25 = hh_data['Опыт работы (месяц)'].quantile(0.25) # вычисляем первый (25-й процентиль)
experience_q75 = hh_data['Опыт работы (месяц)'].quantile(0.75) # вычисляем третий (75-й процентиль)
print(f"Нижний квартиль: {experience_q25}")
print(f"Верхний квартиль: {experience_q75}")

# Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# Для определения анамолий (выбросов) воспользуемся методом межквартильного размаха (IQR)
experience_iqr = experience_q75 - experience_q25
# Вычислим нижнюю и верхнюю границы для выявления аномальных значений
# (если значение находится ниже нижней границы (experience_lower_bound) или выше верхней границы (experience_upper_bound), то оно считается аномальным)
experience_lower_bound = max(0, experience_q25 - 1.5 * experience_iqr)
print(f"Нижняя граница аномальных значений: {experience_lower_bound}")
experience_upper_bound = experience_q75 + 1.5 * experience_iqr
print(f"Верхняя граница аномальных значений: {experience_upper_bound}")
anomalies = hh_data[(hh_data['Опыт работы (месяц)'] < experience_lower_bound) | (hh_data['Опыт работы (месяц)'] > experience_upper_bound)]
print(f"Количество аномальных значений: {anomalies.shape[0]}")
print(f"Аномальные значения: {anomalies['Опыт работы (месяц)'].unique()}")
# Out:
# Мода распределения опыта работа (месяц) соискателей: 81.0
# Минимальный опыт работы (месяц): 1.0
# Максимальный опыт работы (месяц): 1188.0
# Нижний квартиль: 57.0
# Верхний квартиль: 154.0
# Нижняя граница аномальных значений: 0
# Верхняя граница аномальных значений: 299.5
# Количество аномальных значений: 1276
# Аномальные значения: [ 510.  325.  303.  360.  312.  324.  468.  507.  469.  401.  330.  438.
#   417.  389.  370.  334.  321.  442.  377.  317.  302.  357.  358.  300.
#   455.  402.  452.  307.  304.  322.  301.  345.  306.  497.  340.  369.
#   399.  384.  439.  382.  421.  314.  359.  348.  309.  425.  313.  495.
#   310.  400.  347.  423.  308.  429.  315.  411.  338.  363.  383.  373.
#   482.  388.  352.  380.  366.  333.  329.  362.  343.  461.  350.  311.
#   446.  332.  367.  454.  447.  341.  407.  392.  663.  403.  517.  374.
#   316.  424.  337.  305.  414.  467.  356.  390.  355.  394.  418.  420.
# ...

# %% [markdown]
# **Выводы:** <br>
# 1. Мода распределения опыта работы соискателей 81 месяц, т.е. данный опыт работы встречается чаще, чем любой другой опыт работы.<br>
# 2. Крайние значения опыта работы среди соискателей: минимальный опыт - 1 месяц, максимальный опыт - 1188 месяцев.
# 3. Опыт работы большинства соискателей находится в интервале: от 57 до 154 месяцев.
# 4. Распределение опыта работы соискателей можно считать почти нормальным, аномальные значения начинаются с 299,5 месяцев. Однако опыт работы и в 480-600 месяцев (40-50 лет) вполне может быть, если человек начал работать в 18-20 лет и в 60-70 лет ищет работу. А такие соискатели есть, о чем говорят выводы по предыдущему графику распределению возраста соискателей. Следовательно можно считать выбросами значения после 600 месяцев.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака ЗП (руб)? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
plt.figure(figsize=(15, 6))

# Построим гистограмму распределения признака 'ЗП(руб)'
plt.subplot(1, 2, 1)
sns.histplot(hh_data['ЗП (руб)'], bins=25, kde=True)
plt.title('Гистограмма распределения заработной платы (руб)')
plt.xlabel('ЗП (руб)')
plt.ylabel('Количество соискателей')

# Построим коробчатую диаграмму распределения признака 'ЗП(руб)'
plt.subplot(1, 2, 2)
sns.boxplot(x=hh_data['ЗП (руб)'])
plt.title('Коробчатая диаграмма распределения заработной платы (руб)')
plt.xlabel('ЗП (руб)')
# Out:
# Text(0.5, 0, 'ЗП (руб)')

# %%
# Ответы на основные вопросы по распределению ЗП соискателей:

# Чему равна мода распределения?
salary_mode = hh_data['ЗП (руб)'].mode()[0]
print(f"Мода распределения ЗП соискателей: {salary_mode}")

# Каковы предельные значения признака?
salary_min = hh_data['ЗП (руб)'].min()
salary_max = hh_data['ЗП (руб)'].max()
print(f"Минимальная ЗП (руб): {salary_min}")
print(f"Максимальная ЗП (руб): {salary_max}")

# В каком примерном интервале находится заработная плата большинства соискателей?
salary_q25 = hh_data['ЗП (руб)'].quantile(0.25) # вычисляем первый (25-й процентиль)
salary_q75 = hh_data['ЗП (руб)'].quantile(0.75) # вычисляем третий (75-й процентиль)
print(f"Нижний квартиль: {salary_q25}")
print(f"Верхний квартиль: {salary_q75}")

# Есть ли аномалии для признака ЗП(руб)?
# Для определения анамолий (выбросов) воспользуемся методом межквартильного размаха (IQR)
salary_iqr = salary_q75 - salary_q25
# Вычислим нижнюю и верхнюю границы для выявления аномальных значений
# (если значение находится ниже нижней границы (salary_lower_bound) или выше верхней границы (salary_upper_bound), то оно считается аномальным)
salary_lower_bound = max(0, salary_q25 - 1.5 * salary_iqr)
print(f"Нижняя граница аномальных значений: {salary_lower_bound}")
salary_upper_bound = experience_q75 + 1.5 * salary_iqr
print(f"Верхняя граница аномальных значений: {salary_upper_bound}")
anomalies = hh_data[(hh_data['ЗП (руб)'] < salary_lower_bound) | (hh_data['ЗП (руб)'] > salary_upper_bound)]
print(f"Количество аномальных значений: {anomalies.shape[0]}")
print(f"Аномальные значения: {anomalies['ЗП (руб)'].unique()}")
# Out:
# Мода распределения ЗП соискателей: 50000.0
# Минимальная ЗП (руб): 1.0
# Максимальная ЗП (руб): 24304876.0
# Нижний квартиль: 37082.2
# Верхний квартиль: 95000.0
# Нижняя граница аномальных значений: 0
# Верхняя граница аномальных значений: 87030.70000000001
# Количество аномальных значений: 12376
# Аномальные значения: [  100000.       140000.       250000.        90000.       120000.
#    260000.        91896.       170000.       180000.       150000.
#    110000.       139999.       130000.       350000.       160000.
#    155000.       146177.6      355736.7      300000.       135000.
#    500000.       343444.       165000.       400000.       159949.5
#    370000.       200000.       145000.       115000.       185000.
#    399583.25     639602.       190000.       230000.       127000.
#    645171.        95000.       175000.       125065.4      125000.
#    270000.       240000.       280000.       191880.6      129066.
# ...

# %% [markdown]
# **Выводы:** <br>
# 1. Мода распределения ЗП соискателей 50 000, т.е. данная ЗП встречается чаще, чем любая другая ЗП.<br>
# 2. Крайние значения ЗП среди соискателей: минимальная ЗП - 1 руб., максимальная ЗП - 24 304 876 руб, что говорит о  ненормальном распределение данных.
# 3. Желаемая ЗП большинства соискателей находится в интервале: от 37 082.2 до 95 000 руб.
# 4. Распределение ЗП соискателей согласно графикам говорит о ненормальном распределение данных, аномальные значения начинаются с 87 030.70 руб. Однако ЗП от 100 000 до 500 000 вполне может быть. Но сильно бросаются в глаза гигантские размеры желаемой заработной платы от 1 млн. рублей до 24 млн. рублей (требуют 5 соискателей), что можно отнести к выбросам.Так же заработная плата в интервале от 500 тыс. до 1 млн. рублей может быть выбросом. Но это требует дальнейшего анализа для подтверждения.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
# Фильтруем данные по ЗП
filtered_data = hh_data[hh_data['ЗП (руб)'] < 1_000_000]

# Группируем данные по уровню образования и рассчитываем медианную зарплату
median_salary_by_education = filtered_data.groupby('Образование')['ЗП (руб)'].median().reset_index()

# Построим диаграмму зависимости медианной желаемой заработной платы от уровня образования
plt.figure(figsize=(10, 6))
sns.barplot(x='ЗП (руб)', y='Образование', hue='Образование', data=median_salary_by_education, palette='viridis', legend=False)
plt.title('Зависимость медианной желаемой заработной платы от уровня образования')
plt.xlabel('Медианная ЗП (руб)')
plt.ylabel('Уровень образования')
plt.grid(True)

# %% [markdown]
# **Выводы:** <br>
# 1. Для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы?<br>
# Наибольший уровень медианной желаемой заработной платы - 60 тыс. руб.наблюдается у соискателей с высшим образованием, а наименьший - 40 тыс. руб. у соискателей со средним специальным и средним образованием.
# 2. Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?<br>
# Уровень образования несомненно важен при прогнозировании зарабной платы. Как видно из графика наблюдается прямая связь между уровнем образования и ожидаемой заработной платой.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# Фильтруем данные по ЗП
filtered_data = hh_data[hh_data['ЗП (руб)'] < 1_000_000]

# Построим диаграмму распределения желаемой заработной платы в зависимости от города
plt.figure(figsize=(14, 8))
sns.boxplot(x='ЗП (руб)', y='Город', hue='Город', data=filtered_data, palette='viridis', legend=False)
plt.title('Распределение желаемой заработной платы в зависимости от города')
plt.xlabel('ЗП (руб)')
plt.ylabel('Город')
plt.grid(True)

# %% [markdown]
# **Выводы:** <br>
# 1. Как соотносятся медианные уровни желаемой заработной платы и их размах в городах?<br>
# Наибольший уровень медианной желаемой заработной платы как и ее размах отмечается в Москве, далее идет Санкт-Петербург, город-миллионник и другие города.
# 2. Как вы считаете, важен ли признак города при прогнозировании заработной платы?<br>
# Как видно из графика признак города при прогнозировании заработной платы влияет на размер заработной платы, чем крупнее город: Москва и Санкт-Петербург тем заработная плата выше.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
# Группируем данные по готовности к командировкам и переезду, вычисляем медианную ЗП
grouped_data = hh_data.groupby(['Готовность к переезду', 'Готовность к командировкам'])['ЗП (руб)'].median().unstack()

# Построение диаграмму зависимости медианной заработной платы от признаков: готовность к переезду и готовность к командировкам
ax = grouped_data.plot(kind='bar', figsize=(10, 6), colormap='viridis')
plt.title('Зависимость медианной заработной платы от признаков: готовность к переезду и готовность к командировкам')
plt.xlabel('Готовность к переезду')
plt.ylabel('Медианная заработная плата (руб)')
plt.legend(title='Готовность к командировкам')
plt.xticks(rotation=0)
plt.tight_layout()

# %% [markdown]
# **Выводы:** <br>
# Медианная заработная плата больше в категориях, в которых соискатель готов к командировкам. Самая низкая медианная заработная плата у тех соискателей, кто не готов к командировкам и переезду. Таким образом, соискатели, которые готовы на командировки и переезды, хотят получать за свою гибкость к условиям работодателя более высокую заработную плату.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# Создаем сводную таблицу
pivot_table = hh_data.pivot_table(values='ЗП (руб)',
                               index='Возраст',
                               columns='Образование',
                               aggfunc='median')

# Построим тепловую карту зависимости медианной желаемой заработной платы от возраста и образования
plt.figure(figsize=(15, 10))
sns.heatmap(pivot_table, annot=True, cmap='viridis', fmt='.2f', linewidths=0.5)
plt.title('Зависимость медианной желаемой заработной платы от возраста и образования')
plt.xlabel('Образование')
plt.ylabel('Возраст')
plt.tight_layout()

# %% [markdown]
# **Выводы:** <br>
# Как видно из выше построенной зависимости, на всех уровнях образования желаемая медианная заработная плата растет с увеличением возраста, но в группе соискателей с высшим образованием такой рост наиболее быстрый. Также можно отметить, что во всех категориях идет уменьшение заработной платы после достижения определенного возраста.<br>
# Но при всем при этом наблюдается ненормальное скачкообразное распределение данных по ЗП для всех групп после 60 лет. Такие данные выглядят не совсем правдоподобно и требуют дальнейшего изучения.  Так же неправдоподобно выглядит группа соискателей с высшим образованием от 14 до 20 лет и средним специальным образованием от 14 до 18 лет.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
# Преобразуем опыт работы из месяцев в годы
hh_data['Опыт работы (годы)'] = hh_data['Опыт работы (месяц)'] / 12

# Построим диаграмму рассеяния зависимости опыта работы от возраста соискателя
plt.figure(figsize=(10, 6))
plt.scatter(hh_data['Возраст'], hh_data['Опыт работы (годы)'], alpha=0.6, edgecolors='w', s=100, c='blue')
# Добавим прямую
x = np.linspace(0, 100, 100)
plt.plot(x, x, color='red', linestyle='--', label='Опыт работы = Возраст')
plt.title('Зависимость опыта работы от возраста соискателя')
plt.xlabel('Возраст')
plt.ylabel('Опыт работы (годы)')
plt.legend()
plt.grid(True)
plt.tight_layout()

# %% [markdown]
# **Выводы:** <br>
# Как видно из графика, наблюдается прямая зависимость возраста человека от опыта работы, чем больше возраст соискателя, тем больше опыт работы. Но также наблюдаются аномалии в данных: опыт работы не может быть равен возрасту человека и опыт работы не может быть больше возраста человека.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# Фильтруем данные по ЗП
filtered_data = hh_data[hh_data['ЗП (руб)'] < 1000000]

# Построим диаграмму распределения желаемой заработной платы ('ЗП (руб)') в зависимости от пола соискателя ('Пол') и возраста соискателя ('Возраст')
plt.figure(figsize=(15, 6))
sns.catplot(x='Возраст', y='ЗП (руб)', hue='Пол', kind='bar', data=filtered_data, height=6, aspect=2, palette='viridis', errorbar=None)
plt.title('Распределение желаемой заработной платы в зависимости от пола и возраста соискателя')
plt.xlabel('Возраст')
plt.ylabel('Желаемая заработная плата (руб)')
plt.grid(True)
plt.tight_layout()

# %% [markdown]
# **Выводы:** <br>
# Как видно из графика, у мужчин отмечается наибольший желаемый уровень заработной платы и его размах, чем у женщин в одинаковой возрастной группе и с возрастом у мужчин уровень желаемой ЗП растет намного быстрее, чем у женщин.
# Также стоит отметить большое количество аномалий у мужчин, чем у женщин. Так например, возраст мужчин-соискателей начинается от 14 лет и заканчивается возрастом 100 лет, тогда как у женщин возраст женщин-соискателей начинается с 17 лет и заканчивается возрастом 73 года, что более похоже на правду. Стоит также отметить, что самая высокая заработная плата у мужчин 69, 70 лет, что возможно является выбросом.

# %%
plt.figure(figsize=(10, 6))

# Построим диаграмму зависимости пола соискателей от наличия гибкого графика работы
sns.countplot(x='Гибкий график', hue='Пол', data=hh_data, palette='viridis')
plt.title('Зависимость пола соискателей от наличия гибкого графика работы')
plt.xlabel('Гибкий график работы')
plt.ylabel('Количество соискателей')
plt.xticks(ticks=[0, 1], labels=['Нет', 'Да'])
plt.grid(True)
plt.tight_layout()

# %% [markdown]
# **Выводы:** <br>
# Как видно из графика, соискатели с гибким графиком или без него имеют явные различия по полу (мужчины преобладают над женщинами), что может указывать на половые различия в доступности или предпочтениях гибкого графика.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# Найдем полные дубликаты
duplicates = hh_data[hh_data.duplicated(subset=hh_data.columns)]
print(f'Количество полных дубликатов в таблице с резюме: {duplicates.shape[0]}')
# Out:
# Количество полных дубликатов в таблице с резюме: 161

# %%
# Удалим полные дубликаты
hh_data = hh_data.drop_duplicates()

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# Найдем пропущенные значения
null_hh_data = hh_data.isnull().sum()
display(null_hh_data[null_hh_data > 0])
# Out:
# Последнее/нынешнее место работы      1
# Последняя/нынешняя должность         2
# Опыт работы (месяц)                168
# Опыт работы (годы)                 168
# dtype: int64

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# Удалим строки с пропущенными значениями в столбцах: 'Последнее/нынешнее место работы', 'Последняя/нынешняя должность'
hh_data = hh_data.dropna(subset=['Последнее/нынешнее место работы', 'Последняя/нынешняя должность'])
# Заменим пропущенные значения в столбце 'Опыт работы (месяц)' на медиану
hh_data['Опыт работы (месяц)'] = hh_data['Опыт работы (месяц)'].fillna(hh_data['Опыт работы (месяц)'].median())
print(round(hh_data['Опыт работы (месяц)'].mean()))
# Out:
# 114
# <ipython-input-250-96a24c80172d>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# Инициализируем переменные, в которых ЗП аномальная (ниже 1 тыс. руб. и выше 1 млн.руб.)
outliers1 = hh_data[hh_data['ЗП (руб)']<1000]
outliers2 = hh_data[hh_data['ЗП (руб)']>1000000]
print(hh_data[hh_data['ЗП (руб)']<1000].shape[0])
print(hh_data[hh_data['ЗП (руб)']>1000000].shape[0])
# Аномальная ЗП всего соискателей
outliers =hh_data[(hh_data['ЗП (руб)'] > 1e6) | (hh_data['ЗП (руб)'] < 1e3)]
print(outliers.shape[0])
# Out:
# 84
# 5
# 89

# %%
# Удалим резюме с аномальными данными по ЗП
hh_data = hh_data.drop(outliers.index)

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# Инициализируем переменную, в которой опыт работы в годах превышал возраст соискателя или был равен возрасту соискателя
outliers = hh_data[hh_data['Опыт работы (месяц)']/12 >= hh_data['Возраст']]
print(outliers.shape[0])
# Out:
# 7

# %%
# Удалим аномальные резюме, в которых опыт работы в годах превышал возраст соискателя или был равен возрасту соискателя
hh_data = hh_data.drop(outliers.index)

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
# Строим логарифмическую гистограмму с линиями, отображающими среднее и границы интервала метода трех сигм
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
log_age = np.log(hh_data['Возраст'] + 1)
histplot = sns.histplot(log_age, bins=30, ax = ax)
histplot.axvline(log_age.mean(), color='k', lw=2)
histplot.axvline(log_age.mean()+ 4 * log_age.std(), color='k', ls='--', lw=2)
histplot.axvline(log_age.mean()- 3 * log_age.std(), color='k', ls='--', lw=2)
histplot.set_title('Распределение соискателей по возрасту')
histplot.set_ylabel('Количество')

# Инициализируем функцию для определения выбросов с помощью метода z-отклонения.
def outliers_z_score_mod(hh_data, feature, left=3, right=3, log_scale=False):
    if log_scale:
        x = np.log(hh_data[feature]+1)
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = hh_data[(x < lower_bound) | (x > upper_bound)]
    cleaned = hh_data[(x >= lower_bound) & (x <= upper_bound)]
    return outliers, cleaned

outliers, cleaned_data = outliers_z_score_mod(hh_data, 'Возраст', left=3,  right=4, log_scale=True)
print(outliers, outliers.shape[0])
# Out:
#                ЗП       Ищет работу на должность:  \
# 31137  10000 руб.  Менеджер по работе с клиентами
# 32950   2000 руб.                 Тестировщик игр
# 33654  60000 руб.            Frontend-разработчик
#
#       Последнее/нынешнее место работы    Последняя/нынешняя должность  \
# 31137           ООО "ФёрстКэшКомпани"  Менеджер по работе с клиентами
# 32950                        OOO ЖМЫХ                  Тестировщик ПО
# 33654                       Freelance            Frontend-разработчик
#
#       Обновление резюме        Авто          Образование Пол  Возраст  \
# 31137        2019-04-06  Не указано              среднее   М       15
# 32950        2019-04-09  Не указано  среднее специальное   М       15
# 33654        2019-04-19  Не указано  среднее специальное   М      100
#
#        Опыт работы (месяц)  ... Проектная работа  Волонтерство  Стажировка  \
# 31137                  2.0  ...            False         False       False
# ...

# %% [markdown]
# **Выводы:**<br>
# Логарифмическое распределение соискателей по возрасту почти нормальное. Имеет небольшую правостороннюю ассиметрию. Под категорию выбросов попали два соискателя в возрасте 15 лет и один соискатель в возрасте 100 лет.
